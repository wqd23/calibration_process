# %%
# %load_ext autoreload
# %autoreload 2
from lib_reader.reader10.parse_grid_data import parse_grid_data_new
from lib_reader.reader10.analysis_grid_data import cal_sipm_iv_vbr_data, plot_iv_vbr_curve

from addict import Dict
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# IV

# %%
data_iv = Dict(parse_grid_data_new(r'/home/panxf/桌面/GRID-10B/python_Grid10B/data_11B/054_ivscan.dat',data_tag='iv_packet',endian='MSB')[0])
data_vbr = Dict(parse_grid_data_new(r'/home/panxf/桌面/GRID-10B/python_Grid10B/data_11B/054_ivscan.dat',data_tag='vbr_packet',endian='MSB')[0])
plot_iv_vbr_curve(cal_sipm_iv_vbr_data(data_iv.iv,scan_type='iv'),cal_sipm_iv_vbr_data(data_vbr.vbr,scan_type='vbr'))
# Out:
# ========> parsing file  /home/panxf/桌面/GRID-10B/python_Grid10B/data_11B/054_ivscan.dat
#      name  start  size  len
# 0  header      0     4    1
# 1      iv      4     2  200
# ========> parsing file  /home/panxf/桌面/GRID-10B/python_Grid10B/data_11B/054_ivscan.dat
#      name  start  size  len
# 0  header      0     4    1
# 1     vbr      4     2  200
# /home/panxf/桌面/GRID-10B/addhk/python_Grid10B/analysis_grid_data.py:53: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# # WF

# %%
wf_data_l = Dict(parse_grid_data_new(r'005_observe.dat',data_tag='grid1x_wf_packet',endian='MSB')[0])
# wf_data_l.data = wf_data_l.data.astype(np.int16)
# Out:
# ========> parsing file  005_observe.dat
# header
# utc
# pps_for_utc
# timestamp_for_pps
# channel_n
# event_number
# sample_length
# waveform_data
# timestamp
# data_max
# data_base
# CRC
# tail
#                  name  start  size  len
# 0              header      0     4    1
# 1                 utc      4     4    1
# 2         pps_for_utc      8     4    1
# 3   timestamp_for_pps     12     8    1
# 4           channel_n     20     2    1
# 5        event_number     22     4    1
# 6       sample_length     26     2    1
# 7       waveform_data     28     2  256
# 8           timestamp    540     8    1
# 9            data_max    548     2    1
# 10          data_base    550     2    1
# 11                CRC    554     2    1
# 12               tail    556     4    1

# %%
wf_data_l.keys()
# Out:
# dict_keys(['header', 'utc', 'pps_for_utc', 'timestamp_for_pps', 'channel_n', 'event_number', 'sample_length', 'waveform_data', 'timestamp', 'data_max', 'data_base', 'CRC', 'crc_check', 'tail'])

# %%
wf_data_l.waveform_data.shape
# Out:
# (70255, 256)

# %%
plt.plot(wf_data_l.channel_n[wf_data_l.channel_n==0][:])
plt.plot(wf_data_l.channel_n[wf_data_l.channel_n==1][:])
plt.plot(wf_data_l.channel_n[wf_data_l.channel_n==2][:])
plt.plot(wf_data_l.channel_n[wf_data_l.channel_n==3][:])
plt.legend([0,1,2,3])
plt.show()

# %%
plt.plot(wf_data_l.event_number[wf_data_l.channel_n==0][:])
plt.plot(wf_data_l.event_number[wf_data_l.channel_n==1][:])
plt.plot(wf_data_l.event_number[wf_data_l.channel_n==2][:])
plt.plot(wf_data_l.event_number[wf_data_l.channel_n==3][:])
plt.legend([0,1,2,3])
plt.show()

# %%
plt.plot(wf_data_l.sample_length[wf_data_l.channel_n==0][:])
plt.plot(wf_data_l.sample_length[wf_data_l.channel_n==1][:])
plt.plot(wf_data_l.sample_length[wf_data_l.channel_n==2][:])
plt.plot(wf_data_l.sample_length[wf_data_l.channel_n==3][:])

plt.legend([0,1,2,3])
plt.show()

# %%
plt.plot(wf_data_l.waveform_data[wf_data_l.channel_n==0].T[:,2])
plt.plot(wf_data_l.waveform_data[wf_data_l.channel_n==1].T[:,2])
plt.plot(wf_data_l.waveform_data[wf_data_l.channel_n==2].T[:,2])
plt.plot(wf_data_l.waveform_data[wf_data_l.channel_n==3].T[:,2])
# plt.plot(wf_data_l.waveform_data[wf_data_l.channel_n==0].flatten())
# plt.plot(wf_data_l.waveform_data[wf_data_l.channel_n==1].flatten())
# plt.plot(wf_data_l.waveform_data[wf_data_l.channel_n==2].flatten())
# plt.plot(wf_data_l.waveform_data[wf_data_l.channel_n==3].flatten())



plt.legend([0,1,2,3])
plt.show()

# %%
plt.plot(wf_data_l.timestamp[wf_data_l.channel_n==0][:])
plt.plot(wf_data_l.timestamp[wf_data_l.channel_n==1][:])
plt.plot(wf_data_l.timestamp[wf_data_l.channel_n==2][:])
plt.plot(wf_data_l.timestamp[wf_data_l.channel_n==3][:])
plt.legend([0,1,2,3])
plt.show()

# %%
plt.plot(wf_data_l.data_max[wf_data_l.channel_n==0][:])
plt.plot(wf_data_l.data_max[wf_data_l.channel_n==1][:])
plt.plot(wf_data_l.data_max[wf_data_l.channel_n==2][:])
plt.plot(wf_data_l.data_max[wf_data_l.channel_n==3][:])
plt.legend([0,1,2,3])
plt.show()

# %%
plt.plot(wf_data_l.data_base[wf_data_l.channel_n==0][:]/4)
plt.plot(wf_data_l.data_base[wf_data_l.channel_n==1][:]/4)
plt.plot(wf_data_l.data_base[wf_data_l.channel_n==2][:]/4)
plt.plot(wf_data_l.data_base[wf_data_l.channel_n==3][:]/4)
plt.legend([0,1,2,3])
plt.show()

# %%
wf_data_l.keys()
# Out:
# dict_keys(['header', 'utc', 'pps_for_utc', 'timestamp_for_pps', 'channel_n', 'event_number', 'sample_length', 'waveform_data', 'timestamp', 'data_max', 'data_base', 'CRC', 'crc_check', 'tail'])

# %%
plt.plot(wf_data_l.crc_check[wf_data_l.channel_n==0][:])
plt.plot(wf_data_l.crc_check[wf_data_l.channel_n==1][:])
plt.plot(wf_data_l.crc_check[wf_data_l.channel_n==2][:])
plt.plot(wf_data_l.crc_check[wf_data_l.channel_n==3][:])
plt.legend([0,1,2,3])
plt.show()

# %% [markdown]
# # InFO

# %%
wf_data_h = Dict(parse_grid_data_new(r'004_observe.dat',data_tag='grid1x_ft_packet',endian='MSB')[0])
# Out:
# ========> parsing file  004_observe.dat
# header
# utc
# pps_for_utc
# timestamp_for_pps
# channel_n
# event_number
# pkg_event_num
# timestamp
# data_max
# data_base
# {'vary_repeat': '1', 'base_start': '28'}
# CRC
# {'vary_repeat': '1', 'base_start': '28'}
# tail
#                  name  start  size  len
# 0              header      0     4    1
# 1                 utc      4     4    1
# 2         pps_for_utc      8     4    1
# 3   timestamp_for_pps     12     8    1
# 4           channel_n     20     2    1
# 5        event_number     22     4    1
# 6       pkg_event_num     26     2    1
# 7           timestamp     28     8    1
# 8            data_max     36     2    1
# 9           data_base     38     2    1
# 10                CRC    510     2    1
# 11               tail    512     4    1

# %%
wf_data_h.data_max.shape
# Out:
# (50720,)

# %%
wf_data_h.keys()
# Out:
# dict_keys(['header', 'utc', 'pps_for_utc', 'timestamp_for_pps', 'channel_n', 'event_number', 'pkg_event_num', 'timestamp', 'data_max', 'data_base', 'CRC', 'crc_check', 'tail'])

# %%
plt.plot(wf_data_h.utc[wf_data_h.channel_n==0][:])
plt.plot(wf_data_h.utc[wf_data_h.channel_n==1][:])
plt.plot(wf_data_h.utc[wf_data_h.channel_n==2][:])
plt.plot(wf_data_h.utc[wf_data_h.channel_n==3][:])
plt.legend([0,1,2,3])
plt.show()

# %%
plt.plot(wf_data_h.channel_n[wf_data_h.channel_n==0][:])
plt.plot(wf_data_h.channel_n[wf_data_h.channel_n==1][:])
plt.plot(wf_data_h.channel_n[wf_data_h.channel_n==2][:])
plt.plot(wf_data_h.channel_n[wf_data_h.channel_n==3][:])
plt.legend([0,1,2,3])
plt.show()

# %%
# plt.plot(wf_data_h.event_number[wf_data_h.channel_n==0][:])
# plt.plot(wf_data_h.event_number[wf_data_h.channel_n==1][:])
plt.plot(wf_data_h.event_number[wf_data_h.channel_n==2][:])
plt.plot(wf_data_h.event_number[wf_data_h.channel_n==3][:])
plt.legend([0,1,2,3])
plt.show()

# %%
plt.plot(wf_data_h.pkg_event_num[wf_data_h.channel_n==0][:])
plt.plot(wf_data_h.pkg_event_num[wf_data_h.channel_n==1][:])
plt.plot(wf_data_h.pkg_event_num[wf_data_h.channel_n==2][:])
plt.plot(wf_data_h.pkg_event_num[wf_data_h.channel_n==3][:])
plt.legend([0,1,2,3])
plt.show()

# %%
plt.plot(wf_data_h.timestamp[wf_data_h.channel_n==0][:])
plt.plot(wf_data_h.timestamp[wf_data_h.channel_n==1][:])
plt.plot(wf_data_h.timestamp[wf_data_h.channel_n==2][:])
plt.plot(wf_data_h.timestamp[wf_data_h.channel_n==3][:])
plt.legend([0,1,2,3])
plt.show()

# %%
plt.plot(wf_data_h.data_max[wf_data_h.channel_n==0][:])
plt.plot(wf_data_h.data_max[wf_data_h.channel_n==1][:])
plt.plot(wf_data_h.data_max[wf_data_h.channel_n==2][:])
plt.plot(wf_data_h.data_max[wf_data_h.channel_n==3][:])
plt.legend([0,1,2,3])
plt.show()

# %%
# plt.plot(wf_data_h.data_base[wf_data_h.channel_n==0][70500:][:1000]/4)
# plt.plot(wf_data_h.data_base[wf_data_h.channel_n==0][70600:][:50]/4)
# plt.plot(wf_data_h.data_base[wf_data_h.channel_n==1][70600:][:50]/4)
# plt.plot(wf_data_h.data_base[wf_data_h.channel_n==2][70600:][:50]/4)
# plt.plot(wf_data_h.data_base[wf_data_h.channel_n==3][70600:][:50]/4)
plt.plot(wf_data_h.data_base[wf_data_h.channel_n==1][:]/4)
plt.plot(wf_data_h.data_base[wf_data_h.channel_n==2][:]/4)
plt.plot(wf_data_h.data_base[wf_data_h.channel_n==3][:]/4)
plt.legend([0,1,2,3])
plt.show()

# %%
plt.plot(wf_data_h.crc_check[wf_data_h.channel_n==0][:])
plt.plot(wf_data_h.crc_check[wf_data_h.channel_n==1][:])
plt.plot(wf_data_h.crc_check[wf_data_h.channel_n==2][:])
plt.plot(wf_data_h.crc_check[wf_data_h.channel_n==3][:])
plt.legend([0,1,2,3])
plt.show()

# %% [markdown]
# # HK

# %%
# hk_data = Dict(parse_grid_data_new(r'/home/panxf/桌面/GRID-10B/python_Grid10B/data/071_hk_CI_off.dat',data_tag='hk_grid1x_packet',endian='MSB')[0])
# hk_data = Dict(parse/_grid_data_new(r'/home/panxf/桌面/GRID-10B/python_Grid10B/data/072_hk_CI_on.dat',data_tag='hk_grid1x_packet',endian='MSB')[0])
hk_data = Dict(parse_grid_data_new(r'/home/wqd/repo/python/grid_calibration/data/10B/raw_data/x_data/004_hk_53_ch1.dat',data_tag='hk_grid1x_packet',endian='MSB')[0])
# hk_data = Dict(parse_grid_data_new(r'/home/panxf/桌面/GRID-10B/python_Grid10B/data/062_hk.dat',data_tag='hk_grid1x_packet',endian='MSB')[0])
# Out:
# ========> parsing file  data/10B/raw_data/x_data/004_hk_53_ch1.dat
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 # hk_data = Dict(parse_grid_data_new(r'/home/panxf/桌面/GRID-10B/python_Grid10B/data/071_hk_CI_off.dat',data_tag='hk_grid1x_packet',endian='MSB')[0])
#       2 # hk_data = Dict(parse/_grid_data_new(r'/home/panxf/桌面/GRID-10B/python_Grid10B/data/072_hk_CI_on.dat',data_tag='hk_grid1x_packet',endian='MSB')[0])
# ----> 3 hk_data = Dict(parse_grid_data_new(r'data/10B/raw_data/x_data/004_hk_53_ch1.dat',data_tag='hk_grid1x_packet',endian='MSB')[0])
#       4 # hk_data = Dict(parse_grid_data_new(r'/home/panxf/桌面/GRID-10B/python_Grid10B/data/062_hk.dat',data_tag='hk_grid1x_packet',endian='MSB')[0])
#
# File ~/repo/python/grid_calibration/lib_reader/src/lib_reader/reader10/parse_grid_data.py:53, in parse_grid_data_new(file_name, xml_file, data_tag, multi_evt, multi_step, endian, crc_check, data, skip_et, packet_len)
#      46     pattern += re.escape(bytes(tail))
#      47 #else:
#      48 #    pattern += re.escape(bytes(head))
#      49
#      50 #with open(file_name,'rb') as fin:
#      51 #    buffer = fin.read()
#      52 #    index = find_pattern_in_buffer(buffer, pattern)
# ---> 53 buffer = np.fromfile(file_name,dtype=np.uint8) if data is None else data
#      54 index = find_pattern_in_buffer(buffer, pattern)
#      55 if not tail:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/10B/raw_data/x_data/004_hk_53_ch1.dat'

# %%
hk_data.keys()
# Out:
# dict_keys(['header', 'utc_time', 'fee_z5v_v', 'fee_z5v_i', 'fee_z2v1_v', 'fee_z2v1_i', 'fee_z5v4_v', 'fee_z5v4_i', 'fee_z5vA_v', 'fee_z5vA_i', 'fee_5vA_v', 'fee_5vA_i', 'fee_1v8a_v', 'fee_1v8a_i', 'fee_3v3_v', 'fee_3v3_i', 'fee_1v8d_v', 'fee_1v8d_i', 'fee_p5va1_v', 'fee_p5va1_i', 'fee_p5va2_v', 'fee_p5va2_i', 'fee_p5va3_v', 'fee_p5va3_i', 'fee_p5va4_v', 'fee_p5va4_i', 'daq_1v0_v', 'daq_1v0_i', 'daq_1v8_v', 'daq_1v8_i', 'daq_2v5_v', 'daq_2v5_i', 'daq_3v3_v', 'daq_3v3_i', 'daq_1v5_v', 'daq_1v5_i', 'board_temp', 'cpu_temp', 'sipm_voltage0', 'sipm_current0', 'sipm_temp0', 'sipm_voltage1', 'sipm_current1', 'sipm_temp1', 'sipm_voltage2', 'sipm_current2', 'sipm_temp2', 'sipm_voltage3', 'sipm_current3', 'sipm_temp3', 'CRC', 'crc_check'])

# %%
hk_data.utc_time[:]
# Out:
# array([ 328507994,  345285210,  378839642,  395616858,  412394074,
#         429171290,  462725722,  479502938,  496280154,  513057370,
#         529834586,  563389018,  580166234,  596943450,  613720666,
#         647275098,  664052314,  680829530,  697606746,  731161178,
#         747938394,  764715610,  781492826,  798270042,  831824474,
#         848601690,  865378906,  882156122,  915710554,  932487770,
#         949264986,  966042202,  999596634, 1016373850, 1033151066,
#        1049928282, 1066705498, 1100259930, 1117037146, 1133814362,
#        1150591578, 1184146010, 1200923226, 1217700442, 1234477658,
#        1251254874, 1284809306, 1301586522, 1318363738, 1335140954,
#        1368695386, 1385472602, 1402249818, 1419027034, 1452581466,
#        1469358682, 1486135898, 1502913114, 1519690330, 1553244762,
#        1570021978, 1586799194, 1603576410, 1637130842, 1653908058,
#        1670685274, 1687462490, 1721016922, 1737794138, 1754571354,
#        1771348570, 1788125786, 1821680218, 1838457434, 1855234650,
#        1872011866, 1905566298, 1922343514, 1939120730, 1955897946,
#        1972675162, 2006229594, 2023006810, 2039784026, 2056561242,
#        2090115674, 2106892890, 2123670106, 2140447322, 2174001754,
#        2190778970, 2207556186, 2224333402, 2241110618, 2274665050,
#        2291442266, 2308219482, 2324996698, 2358551130, 2375328346,
#        2392105562, 2408882778, 2442437210, 2459214426, 2475991642,
#        2492768858, 2509546074, 2543100506, 2559877722, 2576654938,
#        2593432154, 2626986586, 2643763802, 2660541018, 2677318234,
#        2694095450, 2727649882, 2744427098, 2761204314, 2777981530,
#        2811535962, 2828313178, 2845090394, 2861867610, 2895422042,
#        4103512666, 4137067098, 4153844314, 4170621530, 4187398746,
#        4220953178, 4237730394, 4254507610, 4271284826, 4288062042,
#          26714714,   43491930,   60269146,   77046362,  110600794,
#         127378010,  144155226,  160932442,  177709658,  211264090,
#         228041306,  244818522,  261595738,  295150170,  311927386,
#         328704602,  345481818,  379036250,  395813466,  412590682,
#         429367898,  446145114,  479699546,  496476762,  513253978,
#         530031194,  563585626,  580362842,  597140058,  613917274,
#         647471706,  664248922,  681026138,  697803354,  714580570,
#         748135002,  764912218,  781689434,  798466650,  832021082,
#         848798298,  865575514,  882352730,  899129946,  932684378,
#         949461594,  966238810,  983016026, 1016570458, 1033347674,
#        1050124890, 1066902106, 1100456538, 1117233754, 1134010970,
#        1150788186, 1167565402, 1201119834, 1217897050, 1234674266,
#        1251451482, 1285005914, 1301783130, 1318560346, 1335337562,
#        1368891994, 1385669210, 1402446426, 1419223642, 1436000858,
#        1469555290, 1486332506, 1503109722, 1519886938, 1553441370,
#        1570218586, 1586995802, 1603773018, 1620550234, 1654104666,
#        1670881882, 1687659098, 1704436314, 1737990746, 1754767962,
#        1771545178, 1788322394, 1821876826, 1838654042, 1855431258,
#        1872208474, 1888985690, 1922540122, 1939317338, 1956094554,
#        1972871770, 2006426202, 2023203418, 2039980634, 2056757850,
#        2090312282, 2107089498, 2123866714, 2140643930, 2157421146,
#        2190975578, 2207752794, 2224530010, 2241307226, 2274861658,
#        2291638874, 2308416090, 2325193306, 2341970522, 2375524954,
#        2392302170, 2409079386, 2425856602, 2459411034, 2476188250,
#        2492965466, 2509742682, 2543297114, 2560074330, 2576851546,
#        2593628762, 2610405978, 2643960410, 2660737626, 2677514842,
#        2694292058, 2727846490, 2744623706, 2761400922, 2778178138,
#        2811732570, 2828509786, 2845287002, 2862064218, 2878841434,
#        2912395866, 2929173082, 2945950298, 2962727514, 2996281946,
#        3013059162, 3029836378, 3046613594, 3063390810, 3096945242,
#        3113722458, 3130499674, 3147276890, 3180831322, 3197608538,
#        3214385754, 3231162970, 3264717402, 3281494618, 3298271834,
#        3315049050, 3331826266, 3365380698, 3382157914, 3398935130,
#        3415712346, 3449266778, 3466043994, 3482821210, 3499598426,
#        3533152858, 3549930074, 3566707290, 3583484506, 3600261722,
#        3633816154, 3650593370, 3667370586, 3684147802, 3717702234,
#        3734479450, 3751256666, 3768033882, 3784811098, 3818365530,
#        3835142746, 3851919962, 3868697178, 3902251610, 3919028826,
#        3935806042, 3952583258], dtype=uint32)

# %%
plt.plot(hk_data.sipm_voltage0[:])
plt.plot(hk_data.sipm_voltage1[:])
plt.plot(hk_data.sipm_voltage2[:])
plt.plot(hk_data.sipm_voltage3[:])
plt.legend(['sipm_voltage0','sipm_voltage1','sipm_voltage2','sipm_voltage3'])
plt.show()

# %%
hk_data.keys()
# Out:
# dict_keys(['header', 'utc_time', 'fee_z5v_v', 'fee_z5v_i', 'fee_z2v1_v', 'fee_z2v1_i', 'fee_z5v4_v', 'fee_z5v4_i', 'fee_z5vA_v', 'fee_z5vA_i', 'fee_5vA_v', 'fee_5vA_i', 'fee_1v8a_v', 'fee_1v8a_i', 'fee_3v3_v', 'fee_3v3_i', 'fee_1v8d_v', 'fee_1v8d_i', 'fee_p5va1_v', 'fee_p5va1_i', 'fee_p5va2_v', 'fee_p5va2_i', 'fee_p5va3_v', 'fee_p5va3_i', 'fee_p5va4_v', 'fee_p5va4_i', 'daq_1v0_v', 'daq_1v0_i', 'daq_1v8_v', 'daq_1v8_i', 'daq_2v5_v', 'daq_2v5_i', 'daq_3v3_v', 'daq_3v3_i', 'daq_1v5_v', 'daq_1v5_i', 'board_temp', 'cpu_temp', 'sipm_voltage0', 'sipm_current0', 'sipm_temp0', 'sipm_voltage1', 'sipm_current1', 'sipm_temp1', 'sipm_voltage2', 'sipm_current2', 'sipm_temp2', 'sipm_voltage3', 'sipm_current3', 'sipm_temp3', 'CRC', 'crc_check'])

# %%
hk_data.crc_check
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %%
plt.plot(hk_data.fee_z5v_v[:]*1.25)
plt.plot(hk_data.fee_z2v1_v[:]*1.25)
plt.plot(hk_data.fee_z5v4_v[:]*1.25)
plt.plot(hk_data.fee_z5vA_v[:]*1.25)
plt.legend(['fee_z5v_v','fee_z2v1_v','fee_z5v4_v','fee_z5vA_v'])
plt.show()

# %%
plt.plot(hk_data.fee_z5v_i[:]*2.5/0.02/1e6)
plt.plot(hk_data.fee_z2v1_i[:]*2.5/0.12/1e6)
plt.plot(hk_data.fee_z5v4_i[:]*2.5/0.12/1e6)
plt.plot(hk_data.fee_z5vA_i[:]*2.5/0.12/1e6)
plt.legend(['fee_z5v_i','fee_z2v1_i','fee_z5v4_i','fee_z5vA_i'])
plt.show()

# %%
plt.plot(hk_data.fee_5vA_v[:]*1.25)
plt.plot(hk_data.fee_1v8a_v[:]*1.25)
plt.plot(hk_data.fee_3v3_v[:]*1.25)
plt.plot(hk_data.fee_1v8d_v[:]*1.25)
plt.plot(hk_data.fee_p5va1_v[:]*1.25)
plt.plot(hk_data.fee_p5va2_v[:]*1.25)
plt.plot(hk_data.fee_p5va3_v[:]*1.25)
plt.plot(hk_data.fee_p5va4_v[:]*1.25)

plt.legend(['fee_5vA_v','fee_1v8a_v','fee_3v3_v','fee_1v8d_v','fee_p5va1_v','fee_p5va2_v','fee_p5va3_v','fee_p5va4_v'])
plt.show()

# %%
plt.plot(hk_data.fee_5vA_i[:]*2.5/0.06/1e6)
plt.plot(hk_data.fee_1v8a_i[:]*2.5/0.06/1e6)
plt.plot(hk_data.fee_3v3_i[:]*2.5/0.06/1e6)
plt.plot(hk_data.fee_1v8d_i[:]*2.5/0.06/1e6)
plt.plot(hk_data.fee_p5va1_i[:]*2.5/0.06/1e6)
plt.plot(hk_data.fee_p5va2_i[:]*2.5/0.06/1e6)
plt.plot(hk_data.fee_p5va3_i[:]*2.5/0.06/1e6)
plt.plot(hk_data.fee_p5va4_i[:]*2.5/0.06/1e6)


plt.legend(['fee_5vA_i','fee_1v8a_i','fee_3v3_i','fee_1v8d_i','fee_p5va1_i','fee_p5va2_i','fee_p5va3_i','fee_p5va4_i'])
plt.show()

# %%
plt.plot(hk_data.daq_1v0_v[:]*1.25/1000)
plt.plot(hk_data.daq_1v8_v[:]*1.25/1000)
plt.plot(hk_data.daq_2v5_v[:]*1.25/1000)
plt.plot(hk_data.daq_3v3_v[:]*1.25/1000)
plt.plot(hk_data.daq_1v5_v[:]*1.25/1000)
plt.legend(['daq_1v0_v','daq_1v8_v','daq_2v5_v','daq_3v3_v','daq_1v5_v'])
plt.show()

# %%
plt.plot(hk_data.daq_1v0_i[:]*2.5/0.03/1e6)
plt.plot(hk_data.daq_1v8_i[:]*2.5/0.03/1e6)
plt.plot(hk_data.daq_2v5_i[:]*2.5/0.04/1e6)
plt.plot(hk_data.daq_3v3_i[:]*2.5/0.03/1e6)
plt.plot(hk_data.daq_1v5_i[:]*2.5/0.075/1e6)

plt.legend(['daq_1v0_i','daq_1v8_i','daq_2v5_i','daq_3v3_i','daq_1v5_i'])
plt.show()

# %%
hk_data.keys()
# Out:
# dict_keys(['header', 'utc_time', 'fee_z5v_v', 'fee_z5v_i', 'fee_z2v1_v', 'fee_z2v1_i', 'fee_z5v4_v', 'fee_z5v4_i', 'fee_z5vA_v', 'fee_z5vA_i', 'fee_5vA_v', 'fee_5vA_i', 'fee_1v8a_v', 'fee_1v8a_i', 'fee_3v3_v', 'fee_3v3_i', 'fee_1v8d_v', 'fee_1v8d_i', 'fee_p5va1_v', 'fee_p5va1_i', 'fee_p5va2_v', 'fee_p5va2_i', 'fee_p5va3_v', 'fee_p5va3_i', 'fee_p5va4_v', 'fee_p5va4_i', 'daq_1v0_v', 'daq_1v0_i', 'daq_1v8_v', 'daq_1v8_i', 'daq_2v5_v', 'daq_2v5_i', 'daq_3v3_v', 'daq_3v3_i', 'daq_1v5_v', 'daq_1v5_i', 'board_temp', 'cpu_temp', 'sipm_voltage0', 'sipm_current0', 'sipm_temp0', 'sipm_voltage1', 'sipm_current1', 'sipm_temp1', 'sipm_voltage2', 'sipm_current2', 'sipm_temp2', 'sipm_voltage3', 'sipm_current3', 'sipm_temp3', 'CRC', 'crc_check'])

# %%
plt.plot(hk_data.sipm_current0[:])
plt.plot(hk_data.sipm_current1[:])
plt.plot(hk_data.sipm_current2[:])
plt.plot(hk_data.sipm_current3[:])
plt.legend(['sipm_current0','sipm_current1','sipm_current2','sipm_current3'])
plt.show()

# %%
plt.plot(hk_data.sipm_temp0[:])
plt.plot(hk_data.sipm_temp1[:])
plt.plot(hk_data.sipm_temp2[:])
plt.plot(hk_data.sipm_temp3[:])
plt.legend(['sipm_temp0','sipm_temp1','sipm_temp2','sipm_temp3'])
plt.show()
